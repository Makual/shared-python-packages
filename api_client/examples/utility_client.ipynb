# %% [markdown]
# Install dependencies if necessary.

# %%
# %%bash
#
# GIT_CONFIG_PARAMETERS="'url.https://oauth2:$GIT_PASSWORD@git.ivolga.tech:444/.insteadOf=https://git.ivolga.tech:444/'"
# pip install -r ../requirements.txt

# %% [markdown]
# Import the module:

# %%
from api_client import utility_client

# %% [markdown]
# Using default Client:

# %%
await utility_client.get_embedding(["Расскажи о современных технологиях", "Какие новинки в мире IT?"])

# %%
await utility_client.create_chat_completion([{"role":"user", "content": "Hello World"}])

# %% [markdown]
# Instantiate Client:

# %%
import aio_pika

rabbit_conn = await aio_pika.connect_robust(host="51.250.44.130", port=50602, login="knowledge-base-service", password="<your RABBITMQ_PASSWORD>")
channel = await rabbit_conn.channel()
client = utility_client.Client(channel, {"consuming_log": True, "llm": "openai"})

# %%
await client.get_embedding(["Расскажи о современных технологиях", "Какие новинки в мире IT?"])

# %%
await client.create_chat_completion([{"role":"user", "content": "Hello World"}])

# %%
await rabbit_conn.close()
