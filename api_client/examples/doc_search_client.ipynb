# %% [markdown]
# Install dependencies if necessary.

# %%
# %%bash
#
# GIT_CONFIG_PARAMETERS="'url.https://oauth2:$GIT_PASSWORD@git.ivolga.tech:444/.insteadOf=https://git.ivolga.tech:444/'"
# pip install -r ../requirements.txt

# %% [markdown]
# Import the module:

# %%
from api_client import doc_search_client

# %% [markdown]
# Using default Client:

# %%
await doc_search_client.query_expansion([{"role": "user", "content": "как подключиться к корпоративной сети?"}])

# %%
await doc_search_client.candidates_retrieval(
    {
        'query': 'как подключиться к корпоративной сети?',
        'search_query': 'подключение к корпоративной сети инструкция',
        'hyde': 'Чтобы подключиться к корпоративной сети, убедитесь, что у вас есть необходимые учетные данные, такие как имя пользователя и пароль. Затем откройте VPN-клиент, который используется в вашей компании, и введите эти данные для установления соединения. Если возникнут трудности, обратитесь в IT-отдел для получения помощи.',
        'categories': ['VPN', 'удаленный доступ', 'доступы', 'сеть'],
    },
    2,
)

# %% [markdown]
# Instantiate Client:

# %%
import aio_pika

rabbit_conn = await aio_pika.connect_robust(host="51.250.44.130", port=50602, login="knowledge-base-service", password="<your RABBITMQ_PASSWORD>")
channel = await rabbit_conn.channel()
client = doc_search_client.Client(channel, {"consuming_log": True})

# %%
await client.query_expansion([{"role": "user", "content": "как подключиться к корпоративной сети?"}])

# %%
await client.candidates_retrieval(
    {
        'query': 'как подключиться к корпоративной сети?',
        'search_query': 'подключение к корпоративной сети инструкция',
        'hyde': 'Чтобы подключиться к корпоративной сети, убедитесь, что у вас есть необходимые учетные данные, такие как имя пользователя и пароль. Затем откройте VPN-клиент, который используется в вашей компании, и введите эти данные для установления соединения. Если возникнут трудности, обратитесь в IT-отдел для получения помощи.',
        'categories': ['VPN', 'удаленный доступ', 'доступы', 'сеть'],
    },
    2,
)

# %%
await client.search_result_from_messages([{"role": "user", "content": "как подключиться к корпоративной сети?"}], 2)

# %%
await rabbit_conn.close()
